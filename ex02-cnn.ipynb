# %% [markdown]
# <a href="https://www.kaggle.com/code/ruchui271/ex02-cnn?scriptVersionId=160117105" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
import pandas as pd
import numpy as np
import sklearn
import sklearn.naive_bayes
import sklearn.ensemble as ske
import sklearn.neighbors
import sklearn.pipeline
import sklearn.linear_model
import joblib
from sklearn import preprocessing
from sklearn import tree, linear_model
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.model_selection import train_test_split
from sklearn.feature_selection import SelectFromModel, SelectKBest, mutual_info_classif

import sys
import sqlite3
import importlib
import matplotlib.pyplot as plt
import seaborn as sn
from sklearn import metrics

# %%
import tensorflow as tf
from tensorflow import keras
from keras.layers import Embedding, Conv1D, MaxPooling1D, Dense, Activation, Flatten, Input, Multiply, Dropout, GlobalMaxPooling1D, GlobalAveragePooling1D, AveragePooling1D
from keras.models import Sequential, Model #for keras sequential model
from keras import optimizers

# %%
df_wild = pd.read_pickle('/kaggle/input/wild-pickle/wild.pickle')

# %%
MAX_LENGTH = int(1e6)
prev_size = len(df_wild)
df_wild = df_wild[df_wild['generic_fileSize'] <= MAX_LENGTH]
print("considering samples with size less than {} bytes, {} ----> {}".format(MAX_LENGTH, prev_size, len(df_wild)))
# Out:
# considering samples with size less than 1000000 bytes, 50724 ----> 37354

# %%
df_wild.head()
# Out:
#                                  sample_sha1  benign  malicious  packed  \
# 1   a2aac23e17be570c647fd22080e05b0e58449565    True      False    True
# 2   c3aa534bbd20f3a3dd8e7a457f625291af9d0fe4   False       True    True
# 10  15cb9eab6b0f0ccd718a9235f07046dff100789f   False       True    True
# 12  8792cf08950abada1572b47948e86c9fce26c01a    True      False    True
# 13  353a955ae9919f7b639d74394e3c1149f0189362    True      False    True
#
#    unpacked_sample_sha1  unpacked_sample_id packer_name  \
# 1                    -1                  -1        none
# 2                    -1                  -1        none
# 10                   -1                  -1        none
# 12                   -1                  -1        none
# 13                   -1                  -1        none
#
#     imp_setupremovefilelogentrya  imp_vardeccmp  imp_setdlgitemint  ...  \
# 1                          False          False              False  ...
# 2                          False          False              False  ...
# 10                         False          False              False  ...
# 12                         False          False              False  ...
# 13                         False          False              False  ...
#
#     opcode_xor sub mov  opcode_xor sub mov add  opcode_xor test  \
# 1             0.000022                     0.0         0.000088
# 2             0.000000                     0.0         0.000000
# 10            0.000000                     0.0         0.000000
# 12            0.000000                     0.0         0.000000
# 13            0.000000                     0.0         0.000204
#
#     opcode_xor test je  opcode_xor xor  opcode_xor xor mov  \
# 1             0.000084        0.000070            0.000066
# 2             0.000000        0.000309            0.000000
# 10            0.000000        0.000000            0.000000
# 12            0.000000        0.000000            0.000000
# 13            0.000190        0.000066            0.000091
#
#     opcode_xor xor pop  opcode_xor xor pop mov  opcode_xor xor xor  \
# 1             0.000028                     0.0            0.000053
# 2             0.000000                     0.0            0.000331
# 10            0.000000                     0.0            0.000000
# 12            0.000000                     0.0            0.000000
# 13            0.000000                     0.0            0.000000
#
#     opcode_xor xor xor pop
# 1                      0.0
# 2                      0.0
# 10                     0.0
# 12                     0.0
# 13                     0.0
#
# [5 rows x 56555 columns]

# %%
print(df_wild.shape)
# Out:
# (37354, 56555)

# %%
#Chọn ngẫu nhiên 1,200 mẫu
df = df_wild.sample(n=1200, random_state=102)

# %%
df = df.drop(['sample_sha1','benign','unpacked_sample_sha1','unpacked_sample_id'], axis=1)
df = df.drop(['benign_vt','malicious_vt'], axis=1)

# %%
string_columns = df.select_dtypes(include=['object']).columns
df = df.drop(string_columns, axis=1)

# %%
df.head()
# Out:
#         malicious  packed  imp_setupremovefilelogentrya  imp_vardeccmp  \
# 32148       False    True                         False          False
# 210953      False   False                         False          False
# 50313       False    True                         False          False
# 200288       True    True                         False          False
# 49579        True    True                         False          False
#
#         imp_setdlgitemint  \
# 32148               False
# 210953              False
# 50313               False
# 200288              False
# 49579               False
#
#         imp_?append@?$basic_string@du?$char_traits@d@std@@v?$allocator@d@2@@std@@qaeaav12@abv12@ii@z  \
# 32148                                               False
# 210953                                              False
# 50313                                               False
# 200288                                              False
# 49579                                               False
#
#         imp_zwwritefile  imp_glstencilop  imp_comparelinkinforeferents  \
# 32148             False            False                         False
# 210953            False            False                         False
# 50313             False            False                         False
# 200288            False            False                         False
# 49579             False            False                         False
#
#         imp__setmbcp  ...  opcode_xor sub mov  opcode_xor sub mov add  \
# 32148          False  ...                 0.0                     0.0
# 210953         False  ...                 0.0                     0.0
# 50313          False  ...                 0.0                     0.0
# 200288         False  ...                 0.0                     0.0
# 49579          False  ...                 0.0                     0.0
#
#         opcode_xor test  opcode_xor test je  opcode_xor xor  \
# 32148          0.000187            0.000198             0.0
# 210953         0.000000            0.000000             0.0
# 50313          0.000000            0.000000             0.0
# 200288         0.000000            0.000000             0.0
# 49579          0.000000            0.000000             0.0
#
#         opcode_xor xor mov  opcode_xor xor pop  opcode_xor xor pop mov  \
# 32148                  0.0                 0.0                     0.0
# 210953                 0.0                 0.0                     0.0
# 50313                  0.0                 0.0                     0.0
# 200288                 0.0                 0.0                     0.0
# 49579                  0.0                 0.0                     0.0
#
#         opcode_xor xor xor  opcode_xor xor xor pop
# 32148                  0.0                     0.0
# 210953                 0.0                     0.0
# 50313                  0.0                     0.0
# 200288                 0.0                     0.0
# 49579                  0.0                     0.0
#
# [5 rows x 56526 columns]

# %%
print(df.shape)
# Out:
# (1200, 56526)

# %%
df_train = df.sample(n=1000, random_state=102)
df_test = df.drop(df_train.index)

# %%
data = df_train.sample(n=500, random_state=102)

# %%
#Kiểm tra số lượng mẫu
UB = data[(data['malicious'] == False) & (data['packed'] == False)].shape[0]
PM = data[(data['malicious'] == True) & (data['packed'] == True)].shape[0]
PB = data[(data['malicious'] == False) & (data['packed'] == True)].shape[0]
print('Unpacked Benign: %i samples' % UB)
print('Packed Malware: %i samples' % PM)
print('Packed Benign: %i samples' % PB)
print('Total TRAIN set: %i samples'% (UB+PM+PB))
# Out:
# Unpacked Benign: 39 samples
# Packed Malware: 363 samples
# Packed Benign: 98 samples
# Total TRAIN set: 500 samples

# %%
#Chia tỉ lệ 50 - 50
data_PM = data[(data['malicious'] == True) & (data['packed'] == True)].sample(n=(PM-(UB+PB)), random_state=102)
data = data.drop(data_PM.index)

# %%
#Số lượng tập train
UB = data[(data['malicious'] == False) & (data['packed'] == False)].shape[0]
PM = data[(data['malicious'] == True) & (data['packed'] == True)].shape[0]
PB = data[(data['malicious'] == False) & (data['packed'] == True)].shape[0]
print('Unpacked Benign: %i samples' % UB)
print('Packed Malware: %i samples' % PM)
print('Packed Benign: %i samples' % PB)
print('Total TRAIN set: %i samples'% (UB+PM+PB))
# Out:
# Unpacked Benign: 39 samples
# Packed Malware: 137 samples
# Packed Benign: 98 samples
# Total TRAIN set: 274 samples

# %%
#Xử lý tập train
y = data['malicious'].values
data = data.drop(['malicious','packed'], axis=1)

# %%
UB = df_test[(df_test['malicious'] == False) & (df_test['packed'] == False)].shape[0]
PM = df_test[(df_test['malicious'] == True) & (df_test['packed'] == True)].shape[0]
PB = df_test[(df_test['malicious'] == False) & (df_test['packed'] == True)].shape[0]

df_test_PM = df_test[(df_test['malicious'] == True) & (df_test['packed'] == True)].sample(n=(PM-(UB+PB)), random_state=102)
df_test = df_test.drop(df_test_PM.index)

UB = df_test[(df_test['malicious'] == False) & (df_test['packed'] == False)].shape[0]
PM = df_test[(df_test['malicious'] == True) & (df_test['packed'] == True)].shape[0]
PB = df_test[(df_test['malicious'] == False) & (df_test['packed'] == True)].shape[0]

print('Unpacked Benign: %i samples' % UB)
print('Packed Malware: %i samples' % PM)
print('Packed Benign: %i samples' % PB)
print('Total TEST set: %i samples'% (UB+PM+PB))
# Out:
# Unpacked Benign: 10 samples
# Packed Malware: 46 samples
# Packed Benign: 36 samples
# Total TEST set: 92 samples

# %%
fsel = SelectKBest(score_func=mutual_info_classif, k=100)
fsel.fit(data, y)
features = fsel.get_support(indices = True)
features = [column for column in data.columns[features]]

# %%
# model = SelectFromModel(fsel, prefit=True)
# X = model.transform(data)

X_train = fsel.transform(data)
X_test = fsel.transform(df_test.drop(['malicious','packed'], axis=1))

# Lấy tên đặc trưng tương ứng cho X_train và X_test
X_train = pd.DataFrame(X_train, columns=features)
X_test = pd.DataFrame(X_test, columns=features)

y_train = y
y_test = df_test['malicious'].values

# %%
X_train_array = X_train.values
X_test_array = X_test.values

# Reshape
X_train_new = X_train_array.reshape(X_train_array.shape[0], X_train_array.shape[1], 1)
X_test_new = X_test_array.reshape(X_test_array.shape[0], X_test_array.shape[1], 1)

# %%
n_timesteps, n_features = X_train_new.shape[1], X_train_new.shape[2]

# %%
def Cnn():
    model = Sequential()
    model.add(Input(shape=(n_timesteps,n_features)))
    model.add(Conv1D(filters=256, kernel_size=2, activation='relu', name="Conv1D_1"))
    model.add(Activation('sigmoid'))
    model.add(Conv1D(filters=256, kernel_size=2, name="Conv1D_2"))  
    model.add(MaxPooling1D(pool_size=2, name="MaxPooling1D"))
    model.add(Conv1D(filters=128, kernel_size=3, name="Conv1D_3"))
    model.add(Conv1D(filters=128, kernel_size=3, name="Conv1D_4"))
    model.add(AveragePooling1D(2))
    model.add(Conv1D(filters=64, kernel_size=4, name="Conv1D_5"))
    model.add(Conv1D(filters=64, kernel_size=4, name="Conv1D_6"))
    model.add(GlobalMaxPooling1D())
    model.add(Flatten())
    model.add(Dense(64, activation='relu', name="Dense_1"))
    model.add(Dropout(0.35))
    model.add(Dense(1, activation='sigmoid', name="Dense_2"))
    model.compile(loss='binary_crossentropy',
                  optimizer='adam',
                  metrics=['accuracy'])
    return model

# %%
CNN_model = Cnn()
#print the model summary
CNN_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Conv1D_1 (Conv1D)           (None, 99, 256)           768
#
#  activation (Activation)     (None, 99, 256)           0
#
#  Conv1D_2 (Conv1D)           (None, 98, 256)           131328
#
#  MaxPooling1D (MaxPooling1D  (None, 49, 256)           0
#  )
#
#  Conv1D_3 (Conv1D)           (None, 47, 128)           98432
#
#  Conv1D_4 (Conv1D)           (None, 45, 128)           49280
#
#  average_pooling1d (Average  (None, 22, 128)           0
#  Pooling1D)
#
#  Conv1D_5 (Conv1D)           (None, 19, 64)            32832
#
#  Conv1D_6 (Conv1D)           (None, 16, 64)            16448
#
#  global_max_pooling1d (Glob  (None, 64)                0
#  alMaxPooling1D)
#
#  flatten (Flatten)           (None, 64)                0
#
#  Dense_1 (Dense)             (None, 64)                4160
#
#  dropout (Dropout)           (None, 64)                0
#
#  Dense_2 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 333313 (1.27 MB)
# Trainable params: 333313 (1.27 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
history_cnn = CNN_model.fit(X_train_new, y_train, epochs=100, batch_size=64, validation_data=(X_test_new,y_test), verbose=2)

#for plotting losses curve
loss_training = history_cnn.history['loss']
loss_test = history_cnn.history['val_loss']

#for plotting accyracies curve
accuracy_training = history_cnn.history['accuracy']
accuracy_test = history_cnn.history['val_accuracy']

loss_training = history_cnn.history['loss']
loss_test = history_cnn.history['val_loss']

accuracy_training = history_cnn.history['accuracy']
accuracy_test = history_cnn.history['val_accuracy']

#for Plotting
plt.plot(loss_test)
plt.plot(loss_training)

#set the titles of losses plot
plt.xlabel("# Of Epochs")
plt.ylabel("Loss")
plt.legend(['val Loss', 'Train Loss'])
plt.show()

#set the titles of accuracies plot
plt.plot(accuracy_test)
plt.plot(accuracy_training)
plt.xlabel("# Of Epochs")
plt.ylabel("Accuracy")
plt.legend(['val accuracy', 'Train accuracy'])
plt.show()
# Out:
# Epoch 1/100
# 5/5 - 3s - loss: 1.8872 - accuracy: 0.5000 - val_loss: 1.0999 - val_accuracy: 0.5000 - 3s/epoch - 604ms/step
# Epoch 2/100
# 5/5 - 0s - loss: 0.9564 - accuracy: 0.4854 - val_loss: 0.7048 - val_accuracy: 0.5000 - 500ms/epoch - 100ms/step
# Epoch 3/100
# 5/5 - 0s - loss: 0.7759 - accuracy: 0.5401 - val_loss: 0.7055 - val_accuracy: 0.5000 - 486ms/epoch - 97ms/step
# Epoch 4/100
# 5/5 - 0s - loss: 0.6950 - accuracy: 0.5912 - val_loss: 0.7898 - val_accuracy: 0.5000 - 494ms/epoch - 99ms/step
# Epoch 5/100
# 5/5 - 0s - loss: 0.7657 - accuracy: 0.5730 - val_loss: 0.6385 - val_accuracy: 0.5978 - 494ms/epoch - 99ms/step
# Epoch 6/100
# 5/5 - 0s - loss: 0.5927 - accuracy: 0.6752 - val_loss: 0.7406 - val_accuracy: 0.6522 - 483ms/epoch - 97ms/step
# Epoch 7/100
# 5/5 - 0s - loss: 0.6935 - accuracy: 0.6022 - val_loss: 0.7487 - val_accuracy: 0.5870 - 485ms/epoch - 97ms/step
# Epoch 8/100
# 5/5 - 0s - loss: 0.6780 - accuracy: 0.6387 - val_loss: 0.5759 - val_accuracy: 0.7717 - 484ms/epoch - 97ms/step
# Epoch 9/100
# 5/5 - 0s - loss: 0.5824 - accuracy: 0.6971 - val_loss: 0.5635 - val_accuracy: 0.7717 - 479ms/epoch - 96ms/step
# Epoch 10/100
# 5/5 - 0s - loss: 0.5850 - accuracy: 0.7153 - val_loss: 0.5565 - val_accuracy: 0.6957 - 482ms/epoch - 96ms/step
# Epoch 11/100
# 5/5 - 0s - loss: 0.6101 - accuracy: 0.6861 - val_loss: 0.5637 - val_accuracy: 0.6957 - 477ms/epoch - 95ms/step
# Epoch 12/100
# 5/5 - 0s - loss: 0.5378 - accuracy: 0.7336 - val_loss: 0.5769 - val_accuracy: 0.6848 - 483ms/epoch - 97ms/step
# Epoch 13/100
# 5/5 - 0s - loss: 0.5656 - accuracy: 0.7482 - val_loss: 0.6227 - val_accuracy: 0.6630 - 484ms/epoch - 97ms/step
# Epoch 14/100
# 5/5 - 1s - loss: 0.5854 - accuracy: 0.7336 - val_loss: 0.5522 - val_accuracy: 0.8043 - 530ms/epoch - 106ms/step
# Epoch 15/100
# 5/5 - 0s - loss: 0.5793 - accuracy: 0.7190 - val_loss: 0.5509 - val_accuracy: 0.7717 - 485ms/epoch - 97ms/step
# Epoch 16/100
# 5/5 - 0s - loss: 0.5538 - accuracy: 0.7445 - val_loss: 0.5632 - val_accuracy: 0.6957 - 482ms/epoch - 96ms/step
# Epoch 17/100
# 5/5 - 0s - loss: 0.5755 - accuracy: 0.7190 - val_loss: 0.5889 - val_accuracy: 0.7717 - 488ms/epoch - 98ms/step
# Epoch 18/100
# 5/5 - 0s - loss: 0.5719 - accuracy: 0.7518 - val_loss: 0.5406 - val_accuracy: 0.7174 - 492ms/epoch - 98ms/step
# Epoch 19/100
# 5/5 - 0s - loss: 0.5280 - accuracy: 0.7445 - val_loss: 0.5335 - val_accuracy: 0.6957 - 486ms/epoch - 97ms/step
# Epoch 20/100
# 5/5 - 0s - loss: 0.5421 - accuracy: 0.7445 - val_loss: 0.5174 - val_accuracy: 0.7935 - 481ms/epoch - 96ms/step
# Epoch 21/100
# 5/5 - 0s - loss: 0.6255 - accuracy: 0.6752 - val_loss: 0.5690 - val_accuracy: 0.6848 - 486ms/epoch - 97ms/step
# Epoch 22/100
# 5/5 - 0s - loss: 0.5631 - accuracy: 0.7336 - val_loss: 0.5369 - val_accuracy: 0.6957 - 491ms/epoch - 98ms/step
# Epoch 23/100
# 5/5 - 0s - loss: 0.5566 - accuracy: 0.7372 - val_loss: 0.5281 - val_accuracy: 0.7065 - 486ms/epoch - 97ms/step
# Epoch 24/100
# 5/5 - 0s - loss: 0.5183 - accuracy: 0.7701 - val_loss: 0.5215 - val_accuracy: 0.8152 - 484ms/epoch - 97ms/step
# Epoch 25/100
# 5/5 - 0s - loss: 0.5347 - accuracy: 0.7518 - val_loss: 0.4990 - val_accuracy: 0.8152 - 472ms/epoch - 94ms/step
# Epoch 26/100
# 5/5 - 0s - loss: 0.5068 - accuracy: 0.7445 - val_loss: 0.5213 - val_accuracy: 0.7065 - 482ms/epoch - 96ms/step
# Epoch 27/100
# 5/5 - 0s - loss: 0.5308 - accuracy: 0.7774 - val_loss: 0.5110 - val_accuracy: 0.7500 - 478ms/epoch - 96ms/step
# Epoch 28/100
# 5/5 - 0s - loss: 0.5235 - accuracy: 0.7555 - val_loss: 0.4626 - val_accuracy: 0.8043 - 479ms/epoch - 96ms/step
# Epoch 29/100
# 5/5 - 0s - loss: 0.4825 - accuracy: 0.7701 - val_loss: 0.4581 - val_accuracy: 0.8152 - 497ms/epoch - 99ms/step
# Epoch 30/100
# 5/5 - 0s - loss: 0.4589 - accuracy: 0.7883 - val_loss: 0.4448 - val_accuracy: 0.7717 - 480ms/epoch - 96ms/step
# Epoch 31/100
# 5/5 - 0s - loss: 0.4135 - accuracy: 0.8175 - val_loss: 0.5263 - val_accuracy: 0.7717 - 477ms/epoch - 95ms/step
# Epoch 32/100
# 5/5 - 0s - loss: 0.4822 - accuracy: 0.7737 - val_loss: 0.4208 - val_accuracy: 0.8152 - 489ms/epoch - 98ms/step
# Epoch 33/100
# 5/5 - 0s - loss: 0.4117 - accuracy: 0.8102 - val_loss: 0.4479 - val_accuracy: 0.8043 - 469ms/epoch - 94ms/step
# Epoch 34/100
# 5/5 - 0s - loss: 0.4386 - accuracy: 0.8175 - val_loss: 0.5046 - val_accuracy: 0.7065 - 490ms/epoch - 98ms/step
# Epoch 35/100
# 5/5 - 1s - loss: 0.4776 - accuracy: 0.7555 - val_loss: 0.5006 - val_accuracy: 0.7717 - 642ms/epoch - 128ms/step
# Epoch 36/100
# 5/5 - 1s - loss: 0.5075 - accuracy: 0.7445 - val_loss: 0.4662 - val_accuracy: 0.7065 - 650ms/epoch - 130ms/step
# Epoch 37/100
# 5/5 - 1s - loss: 0.4253 - accuracy: 0.7920 - val_loss: 0.4227 - val_accuracy: 0.8152 - 606ms/epoch - 121ms/step
# Epoch 38/100
# 5/5 - 1s - loss: 0.4057 - accuracy: 0.8285 - val_loss: 0.4009 - val_accuracy: 0.7935 - 510ms/epoch - 102ms/step
# Epoch 39/100
# 5/5 - 0s - loss: 0.4068 - accuracy: 0.7993 - val_loss: 0.5282 - val_accuracy: 0.7717 - 475ms/epoch - 95ms/step
# Epoch 40/100
# 5/5 - 0s - loss: 0.4513 - accuracy: 0.7920 - val_loss: 0.3745 - val_accuracy: 0.8043 - 479ms/epoch - 96ms/step
# Epoch 41/100
# 5/5 - 0s - loss: 0.3731 - accuracy: 0.8285 - val_loss: 0.4145 - val_accuracy: 0.7717 - 480ms/epoch - 96ms/step
# Epoch 42/100
# 5/5 - 0s - loss: 0.3456 - accuracy: 0.8175 - val_loss: 0.3606 - val_accuracy: 0.8370 - 488ms/epoch - 98ms/step
# Epoch 43/100
# 5/5 - 0s - loss: 0.3520 - accuracy: 0.8285 - val_loss: 0.3568 - val_accuracy: 0.8478 - 488ms/epoch - 98ms/step
# Epoch 44/100
# 5/5 - 0s - loss: 0.3511 - accuracy: 0.8394 - val_loss: 0.4089 - val_accuracy: 0.7935 - 481ms/epoch - 96ms/step
# Epoch 45/100
# 5/5 - 0s - loss: 0.3863 - accuracy: 0.8175 - val_loss: 0.3654 - val_accuracy: 0.8478 - 476ms/epoch - 95ms/step
# Epoch 46/100
# 5/5 - 0s - loss: 0.3654 - accuracy: 0.8212 - val_loss: 0.5801 - val_accuracy: 0.6522 - 478ms/epoch - 96ms/step
# Epoch 47/100
# 5/5 - 0s - loss: 0.4113 - accuracy: 0.7774 - val_loss: 0.4642 - val_accuracy: 0.7935 - 479ms/epoch - 96ms/step
# Epoch 48/100
# 5/5 - 0s - loss: 0.3395 - accuracy: 0.8431 - val_loss: 0.4385 - val_accuracy: 0.7174 - 488ms/epoch - 98ms/step
# Epoch 49/100
# 5/5 - 0s - loss: 0.3728 - accuracy: 0.8212 - val_loss: 0.3719 - val_accuracy: 0.8043 - 482ms/epoch - 96ms/step
# Epoch 50/100
# 5/5 - 0s - loss: 0.3129 - accuracy: 0.8504 - val_loss: 0.4736 - val_accuracy: 0.7935 - 483ms/epoch - 97ms/step
# Epoch 51/100
# 5/5 - 1s - loss: 0.3906 - accuracy: 0.8285 - val_loss: 0.4494 - val_accuracy: 0.7065 - 500ms/epoch - 100ms/step
# Epoch 52/100
# 5/5 - 0s - loss: 0.3484 - accuracy: 0.7920 - val_loss: 0.4161 - val_accuracy: 0.7935 - 484ms/epoch - 97ms/step
# Epoch 53/100
# 5/5 - 0s - loss: 0.3567 - accuracy: 0.8175 - val_loss: 0.3665 - val_accuracy: 0.7717 - 484ms/epoch - 97ms/step
# Epoch 54/100
# 5/5 - 1s - loss: 0.3264 - accuracy: 0.8285 - val_loss: 0.3715 - val_accuracy: 0.7826 - 523ms/epoch - 105ms/step
# Epoch 55/100
# 5/5 - 0s - loss: 0.3030 - accuracy: 0.8321 - val_loss: 0.3509 - val_accuracy: 0.8261 - 479ms/epoch - 96ms/step
# Epoch 56/100
# 5/5 - 0s - loss: 0.3079 - accuracy: 0.8394 - val_loss: 0.3543 - val_accuracy: 0.8478 - 486ms/epoch - 97ms/step
# Epoch 57/100
# 5/5 - 0s - loss: 0.2787 - accuracy: 0.8759 - val_loss: 0.3832 - val_accuracy: 0.8152 - 471ms/epoch - 94ms/step
# Epoch 58/100
# 5/5 - 0s - loss: 0.2872 - accuracy: 0.8613 - val_loss: 0.3648 - val_accuracy: 0.8478 - 477ms/epoch - 95ms/step
# Epoch 59/100
# 5/5 - 0s - loss: 0.3003 - accuracy: 0.8358 - val_loss: 0.3561 - val_accuracy: 0.7935 - 497ms/epoch - 99ms/step
# Epoch 60/100
# 5/5 - 0s - loss: 0.2798 - accuracy: 0.8467 - val_loss: 0.3563 - val_accuracy: 0.8043 - 491ms/epoch - 98ms/step
# Epoch 61/100
# 5/5 - 0s - loss: 0.3068 - accuracy: 0.8321 - val_loss: 0.4083 - val_accuracy: 0.8261 - 484ms/epoch - 97ms/step
# Epoch 62/100
# 5/5 - 0s - loss: 0.2927 - accuracy: 0.8504 - val_loss: 0.3516 - val_accuracy: 0.8152 - 481ms/epoch - 96ms/step
# Epoch 63/100
# 5/5 - 0s - loss: 0.2726 - accuracy: 0.8759 - val_loss: 0.3490 - val_accuracy: 0.8587 - 490ms/epoch - 98ms/step
# Epoch 64/100
# 5/5 - 0s - loss: 0.2636 - accuracy: 0.8942 - val_loss: 0.3554 - val_accuracy: 0.8478 - 493ms/epoch - 99ms/step
# Epoch 65/100
# 5/5 - 0s - loss: 0.2784 - accuracy: 0.8613 - val_loss: 0.3783 - val_accuracy: 0.8261 - 471ms/epoch - 94ms/step
# Epoch 66/100
# 5/5 - 0s - loss: 0.2851 - accuracy: 0.8869 - val_loss: 0.4738 - val_accuracy: 0.7500 - 476ms/epoch - 95ms/step
# Epoch 67/100
# 5/5 - 0s - loss: 0.3206 - accuracy: 0.8175 - val_loss: 0.3938 - val_accuracy: 0.8152 - 481ms/epoch - 96ms/step
# Epoch 68/100
# 5/5 - 0s - loss: 0.2638 - accuracy: 0.8869 - val_loss: 0.3698 - val_accuracy: 0.8587 - 486ms/epoch - 97ms/step
# Epoch 69/100
# 5/5 - 0s - loss: 0.2669 - accuracy: 0.8540 - val_loss: 0.3606 - val_accuracy: 0.8370 - 478ms/epoch - 96ms/step
# Epoch 70/100
# 5/5 - 0s - loss: 0.2635 - accuracy: 0.8723 - val_loss: 0.3485 - val_accuracy: 0.8696 - 480ms/epoch - 96ms/step
# Epoch 71/100
# 5/5 - 0s - loss: 0.2575 - accuracy: 0.8869 - val_loss: 0.3709 - val_accuracy: 0.8043 - 473ms/epoch - 95ms/step
# Epoch 72/100
# 5/5 - 1s - loss: 0.2589 - accuracy: 0.8723 - val_loss: 0.3680 - val_accuracy: 0.8152 - 503ms/epoch - 101ms/step
# Epoch 73/100
# 5/5 - 0s - loss: 0.2521 - accuracy: 0.8686 - val_loss: 0.3530 - val_accuracy: 0.8478 - 487ms/epoch - 97ms/step
# Epoch 74/100
# 5/5 - 1s - loss: 0.2422 - accuracy: 0.8832 - val_loss: 0.5040 - val_accuracy: 0.7283 - 508ms/epoch - 102ms/step
# Epoch 75/100
# 5/5 - 1s - loss: 0.3044 - accuracy: 0.8394 - val_loss: 0.4444 - val_accuracy: 0.8261 - 530ms/epoch - 106ms/step
# Epoch 76/100
# 5/5 - 0s - loss: 0.2674 - accuracy: 0.8577 - val_loss: 0.3541 - val_accuracy: 0.8587 - 472ms/epoch - 94ms/step
# Epoch 77/100
# 5/5 - 0s - loss: 0.2712 - accuracy: 0.8796 - val_loss: 0.3425 - val_accuracy: 0.8804 - 481ms/epoch - 96ms/step
# Epoch 78/100
# 5/5 - 0s - loss: 0.2809 - accuracy: 0.8613 - val_loss: 0.3900 - val_accuracy: 0.7283 - 475ms/epoch - 95ms/step
# Epoch 79/100
# 5/5 - 0s - loss: 0.2812 - accuracy: 0.8577 - val_loss: 0.3806 - val_accuracy: 0.8587 - 475ms/epoch - 95ms/step
# Epoch 80/100
# 5/5 - 0s - loss: 0.2479 - accuracy: 0.8832 - val_loss: 0.3461 - val_accuracy: 0.8696 - 473ms/epoch - 95ms/step
# Epoch 81/100
# 5/5 - 0s - loss: 0.2082 - accuracy: 0.9051 - val_loss: 0.3709 - val_accuracy: 0.8913 - 480ms/epoch - 96ms/step
# Epoch 82/100
# 5/5 - 0s - loss: 0.2395 - accuracy: 0.8869 - val_loss: 0.3886 - val_accuracy: 0.8478 - 477ms/epoch - 95ms/step
# Epoch 83/100
# 5/5 - 0s - loss: 0.2369 - accuracy: 0.8796 - val_loss: 0.3976 - val_accuracy: 0.8478 - 478ms/epoch - 96ms/step
# Epoch 84/100
# 5/5 - 0s - loss: 0.2261 - accuracy: 0.9124 - val_loss: 0.4113 - val_accuracy: 0.8696 - 477ms/epoch - 95ms/step
# Epoch 85/100
# 5/5 - 0s - loss: 0.2470 - accuracy: 0.8832 - val_loss: 0.4072 - val_accuracy: 0.8152 - 484ms/epoch - 97ms/step
# Epoch 86/100
# 5/5 - 0s - loss: 0.2317 - accuracy: 0.9124 - val_loss: 0.3948 - val_accuracy: 0.8587 - 474ms/epoch - 95ms/step
# Epoch 87/100
# 5/5 - 0s - loss: 0.2367 - accuracy: 0.8942 - val_loss: 0.4730 - val_accuracy: 0.8261 - 480ms/epoch - 96ms/step
# Epoch 88/100
# 5/5 - 0s - loss: 0.2492 - accuracy: 0.8832 - val_loss: 0.3935 - val_accuracy: 0.8261 - 476ms/epoch - 95ms/step
# Epoch 89/100
# 5/5 - 0s - loss: 0.2167 - accuracy: 0.9124 - val_loss: 0.4230 - val_accuracy: 0.8478 - 482ms/epoch - 96ms/step
# Epoch 90/100
# 5/5 - 0s - loss: 0.2086 - accuracy: 0.9197 - val_loss: 0.3864 - val_accuracy: 0.8696 - 468ms/epoch - 94ms/step
# Epoch 91/100
# 5/5 - 0s - loss: 0.1894 - accuracy: 0.9161 - val_loss: 0.3954 - val_accuracy: 0.8913 - 475ms/epoch - 95ms/step
# Epoch 92/100
# 5/5 - 0s - loss: 0.1953 - accuracy: 0.9270 - val_loss: 0.4172 - val_accuracy: 0.8696 - 475ms/epoch - 95ms/step
# Epoch 93/100
# 5/5 - 0s - loss: 0.1866 - accuracy: 0.9161 - val_loss: 0.4295 - val_accuracy: 0.8370 - 473ms/epoch - 95ms/step
# Epoch 94/100
# 5/5 - 0s - loss: 0.2679 - accuracy: 0.8832 - val_loss: 0.3939 - val_accuracy: 0.8587 - 487ms/epoch - 97ms/step
# Epoch 95/100
# 5/5 - 1s - loss: 0.2263 - accuracy: 0.9015 - val_loss: 0.3969 - val_accuracy: 0.8478 - 528ms/epoch - 106ms/step
# Epoch 96/100
# 5/5 - 0s - loss: 0.2260 - accuracy: 0.9015 - val_loss: 0.3653 - val_accuracy: 0.8478 - 488ms/epoch - 98ms/step
# Epoch 97/100
# 5/5 - 0s - loss: 0.2066 - accuracy: 0.8905 - val_loss: 0.4610 - val_accuracy: 0.7935 - 482ms/epoch - 96ms/step
# Epoch 98/100
# 5/5 - 0s - loss: 0.2466 - accuracy: 0.8869 - val_loss: 0.3646 - val_accuracy: 0.9022 - 481ms/epoch - 96ms/step
# Epoch 99/100
# 5/5 - 0s - loss: 0.2402 - accuracy: 0.8978 - val_loss: 0.3785 - val_accuracy: 0.8804 - 476ms/epoch - 95ms/step
# Epoch 100/100
# 5/5 - 1s - loss: 0.1730 - accuracy: 0.9343 - val_loss: 0.4398 - val_accuracy: 0.8261 - 508ms/epoch - 102ms/step

# %%
#calculate and print the validation accuracy
scores = CNN_model.evaluate(X_train_new, y_train)
print('Final validation accuraccy: ')
print("Loss:", scores[0], " Accuracy:", scores[1])
# Out:
# 9/9 [==============================] - 0s 21ms/step - loss: 0.2016 - accuracy: 0.8905
# Final validation accuraccy:
# Loss: 0.20156553387641907  Accuracy: 0.8905109763145447

# %%
#calculate and print the testing accuracy
scores_test = CNN_model.evaluate(X_test_new, y_test)
print('Final testing accuraccy: ')
print("Loss:", scores_test[0], " Accuracy:", scores_test[1])
# Out:
# 3/3 [==============================] - 0s 18ms/step - loss: 0.4398 - accuracy: 0.8261
# Final testing accuraccy:
# Loss: 0.4397972822189331  Accuracy: 0.8260869383811951

# %%
#make the model prediction
pred = CNN_model.predict(X_test_new)
# Out:
# 3/3 [==============================] - 0s 19ms/step

# %%
Y_pred = (pred > 0.5) * 1.0
Y_pred = Y_pred.reshape(y_test.shape)

# %%
report = metrics.classification_report(y_test, Y_pred)
print("Classification Report:\n", report)
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#        False       0.94      0.70      0.80        46
#         True       0.76      0.96      0.85        46
#
#     accuracy                           0.83        92
#    macro avg       0.85      0.83      0.82        92
# weighted avg       0.85      0.83      0.82        92

# %%
class_labels = list(X_test_new)

# %%
import seaborn as sns
cm = confusion_matrix(y_test, Y_pred)

# Hiển thị confusion matrix bằng heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=['Malware', 'Benign'],
            yticklabels=['Malware', 'Benign'])
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()
